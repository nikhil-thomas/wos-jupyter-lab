# %% [markdown]
# # 05 Managing Pods

# %% [markdown]
# - abstraction of a server (virtual machine, host ?)
# - multiple containrers under same namepsace exposef at a single ip

# %% [markdown]
# - deployments are used to schdule pods
# -naked pods are not re-scheduled in case of nore failure

# %% [markdown]
# ---
# ## kubectl run
#
# ```
# kubectl run <podname> --image=<imagename:tag>
# ```

# %% [markdown]
# ### busybox.yaml
# ```
# apiVersion: v1
# kind: Pod
# metadata:
#   Name: busybox2
#   Namespace: default
# spec:
#   containers:
#   - name: busy
#     image: busybox
#     command:
#     - sleep
#     - "3600"
# ```

# %% [markdown]
# ### kubectl replace
#
# - works similar to `apply`, but the existing resource is deleted and then recreated

# %% [markdown]
# ### kubectl edit
#
# - open an exisitng resource manifest in vi and edit the manifest
#
# 162
